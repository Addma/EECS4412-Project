# %%
import pandas as pd
import json
df = pd.read_json("./yelp_dataset/yelp_academic_dataset_business.json", lines=True)
sample1 = pd.read_csv("./resources/business_sample.csv")

# %%
sample2 = df[df['business_id'].isin(sample1['business_id'])]

# %%
sample2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 709 to 149253
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   200 non-null    object
#  1   name          200 non-null    object
#  2   address       200 non-null    object
#  3   city          200 non-null    object
#  4   state         200 non-null    object
#  5   postal_code   200 non-null    object
#  6   latitude      200 non-null    float64
#  7   longitude     200 non-null    float64
#  8   stars         200 non-null    float64
#  9   review_count  200 non-null    int64
#  10  is_open       200 non-null    int64
#  11  attributes    196 non-null    object
#  12  categories    200 non-null    object
#  13  hours         176 non-null    object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 23.4+ KB

# %%
temp = df['attributes'].tolist()

# %%
type(temp)
# Out:
# list

# %%
temp
# Out:
# [{'ByAppointmentOnly': 'True'},
#  {'BusinessAcceptsCreditCards': 'True'},
#  {'BikeParking': 'True',
#   'BusinessAcceptsCreditCards': 'True',
#   'RestaurantsPriceRange2': '2',
#   'CoatCheck': 'False',
#   'RestaurantsTakeOut': 'False',
#   'RestaurantsDelivery': 'False',
#   'Caters': 'False',
#   'WiFi': "u'no'",
#   'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#   'WheelchairAccessible': 'True',
#   'HappyHour': 'False',
#   'OutdoorSeating': 'False',
#   'HasTV': 'False',
#   'RestaurantsReservations': 'False',
#   'DogsAllowed': 'False',
#   'ByAppointmentOnly': 'False'},
#  {'RestaurantsDelivery': 'False',
#   'OutdoorSeating': 'False',
#   'BusinessAcceptsCreditCards': 'False',
#   'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#   'BikeParking': 'True',
#   'RestaurantsPriceRange2': '1',
#   'RestaurantsTakeOut': 'True',
#   'ByAppointmentOnly': 'False',
# ...

# %%
temp[0]['ByAppointmentOnly'] == 'True'
# Out:
# True

# %%
temp[2]['BusinessParking']
# Out:
# "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}"

# %%
sample1['attributes'].head(20)
# Out:
# 0     {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 1     {'GoodForMeal': "{'dessert': False, 'latenight...
# 2     {'BusinessParking': "{'garage': False, 'street...
# 3     {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 4     {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 5     {'RestaurantsReservations': 'False', 'Restaura...
# 6     {'GoodForKids': 'False', 'Alcohol': "u'full_ba...
# 7     {'GoodForKids': 'False', 'RestaurantsAttire': ...
# 8     {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 9     {'RestaurantsGoodForGroups': 'True', 'GoodForK...
# 10    {'BusinessAcceptsCreditCards': 'True', 'Outdoo...
# 11    {'RestaurantsDelivery': 'False', 'HasTV': 'Tru...
# 12    {'Alcohol': "u'none'", 'HasTV': 'False', 'Busi...
# 13    {'Alcohol': "u'full_bar'", 'NoiseLevel': "u'av...
# 14    {'RestaurantsTableService': 'True', 'Restauran...
# 15    {'WiFi': "'no'", 'NoiseLevel': "'average'", 'R...
# 16    {'Caters': 'True', 'RestaurantsReservations': ...
# ...
