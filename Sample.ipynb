# %%
import pandas as pd
df = pd.read_json("./yelp_dataset/yelp_academic_dataset_business.json", lines=True)

# %%
df.dropna()
# Out:
#                    business_id                      name  \
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 5       CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# ...                        ...                       ...
# 150340  hn9Toz3s-Ei3uZPt7esExA     West Side Kebab House
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address          city state postal_code  \
# 1       87 Grasso Plaza Shopping Center        Affton    MO       63123
# 2                  5255 E Broadway Blvd        Tucson    AZ       85711
# ...

# %%
rest = df[df['categories'].str.contains('Restaurants', na=False)].sample(200)
rest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 31780 to 130715
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   200 non-null    object
#  1   name          200 non-null    object
#  2   address       200 non-null    object
#  3   city          200 non-null    object
#  4   state         200 non-null    object
#  5   postal_code   200 non-null    object
#  6   latitude      200 non-null    float64
#  7   longitude     200 non-null    float64
#  8   stars         200 non-null    float64
#  9   review_count  200 non-null    int64
#  10  is_open       200 non-null    int64
#  11  attributes    196 non-null    object
#  12  categories    200 non-null    object
#  13  hours         176 non-null    object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 23.4+ KB

# %%
rest.to_csv('./test.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 rest.to_csv('./test.csv')
#
# File c:\users\pozzy\appdata\local\programs\python\python310\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
# ...
